# %% [markdown]
# <a href="https://colab.research.google.com/github/abiodunarabaa/Movie-Analysis-and-Comparison/blob/main/Movies_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Setting up matplotlib to display plots inline
# %matplotlib inline

# Setting default figure size for matplotlib
plt.rcParams['figure.figsize'] = (12, 8)

# %%
# Reading in the data from 'movies.csv'
dataframe = pd.read_csv('movies.csv')

# Displaying the first 5 rows of the dataframe
dataframe.head(10)

df = dataframe

# %%
# Checking for missing data in each column
for col in df.columns:
    # Calculating the percentage of missing values in the column
    percent_missing = np.mean(df[col].isnull()) * 100
    # Printing the column name and the percentage of missing values
    print('{} - {:.2f}%'.format(col, percent_missing))
# Out:
# name - 0.00%
# rating - 1.00%
# genre - 0.00%
# year - 0.00%
# released - 0.03%
# score - 0.04%
# votes - 0.04%
# director - 0.00%
# writer - 0.04%
# star - 0.01%
# country - 0.04%
# budget - 28.31%
# gross - 2.46%
# company - 0.22%
# runtime - 0.05%

# %%
# Dropping rows with missing values
df = df.dropna()

# %%
# Checking for missing data again
for col in df.columns:
    # Calculating the percentage of missing values in the column
    percent_missing = np.mean(df[col].isnull()) * 100
    # Printing the column name and the percentage of missing values
    print('{} - {:.3f}%'.format(col, percent_missing))
# Out:
# name - 0.000%
# rating - 0.000%
# genre - 0.000%
# year - 0.000%
# released - 0.000%
# score - 0.000%
# votes - 0.000%
# director - 0.000%
# writer - 0.000%
# star - 0.000%
# country - 0.000%
# budget - 0.000%
# gross - 0.000%
# company - 0.000%
# runtime - 0.000%

# %%
# Checking the data types of columns
data_types = df.dtypes
print(data_types)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Removing the 'year' column from the DataFrame
df.drop('year', axis = 1, inplace = True)
# Out:
# <ipython-input-26-75eb73345bdd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('year', axis = 1, inplace = True)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
# Extracting the year from the 'released' column and creating a new 'year' column
df['year'] = int(df['released'].values.tolist()[0].split(',')[1][1:5])
# Out:
# <ipython-input-28-dddc4458d49a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = int(df['released'].values.tolist()[0].split(',')[1][1:5])

# %%
# order the data by gross

df.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score      votes  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0
# ...

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
# @title score vs votes

correlation_matrix.plot(kind='scatter', x='score', y='votes', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title votes vs budget

correlation_matrix.plot(kind='scatter', x='votes', y='budget', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title runtime vs rating

def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['runtime']
  ys = series['rating']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df_numerized.sort_values('runtime', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('runtime')
_ = plt.ylabel('rating')

# %%
# @title runtime vs genre

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['runtime']
  ys = series['genre']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df_numerized.sort_values('runtime', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('runtime')
_ = plt.ylabel('genre')

# %%
# Budget vs Gross with regression line
sns.regplot(x='budget', y='gross', data=df, line_kws={'color': 'red'})
plt.title('Budget vs Gross')
plt.xlabel('Budget for film')
plt.ylabel('Gross earnings')
plt.show()

# %%
# Budget vs Gross
plt.scatter(x='budget', y='gross', data=df)
plt.title('Budget vs Gross')
plt.xlabel('Budget for film')
plt.ylabel('Gross earnings')
plt.show()

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# <ipython-input-34-f471181e404f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#             score     votes    budget     gross   runtime  year
# score    1.000000  0.474256  0.072001  0.222556  0.414068   NaN
# votes    0.474256  1.000000  0.439675  0.614751  0.352303   NaN
# budget   0.072001  0.439675  1.000000  0.740247  0.318695   NaN
# gross    0.222556  0.614751  0.740247  1.000000  0.275796   NaN
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000   NaN
# year          NaN       NaN       NaN       NaN       NaN   NaN

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix for Numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
# Out:
# Text(120.72222222222221, 0.5, 'Movie features')

# %%
df_numerized = df.copy()

for col in df_numerized.columns:
    if df_numerized[col].dtype == 'object':
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

df_numerized
# Out:
#       name  rating  genre  released  score      votes  director  writer  star  \
# 0     4692       6      6      1304    8.4   927000.0      1795    2832   699
# 1     3929       6      1      1127    5.8    65000.0      1578    1158   214
# 2     3641       4      0      1359    8.7  1200000.0       757    1818  1157
# 3      204       4      4      1127    7.7   221000.0       889    1413  1474
# 4      732       6      4      1170    7.3   108000.0       719     351   271
# ...    ...     ...    ...       ...    ...        ...       ...     ...   ...
# 7648   415       6      0       904    6.6   140000.0        16    2390  1812
# 7649  3556       4      0       713    6.5   102000.0       852    2309   147
# 7650  1153       4      1       904    5.6    53000.0      1809    2827  1470
# 7651  3978       4      1       758    6.8    42000.0       294    2091   640
# 7652  4090       3      0       370    6.8     3700.0       746    1184  1839
#
# ...

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation matrix for Numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

# It seems like the company that doesn't correlate with gross
# Out:
# Text(120.72222222222221, 0.5, 'Movie features')
